# %%
# %store -r data_cat

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Por el tiempo transcurrido

# %% [markdown]
# #### 5. ¿Cómo ha cambiado el volumen de los videos en tendencia a lo largo del tiempo?

# %% [markdown]
# En primer lugar, se necesita identificar el rango de fechas del dataset.

# %%
data_cat.sort_values(by="trending_date").head()
# Out:
#           video_id                                              title  \
# 16280  xnvlaasnhHg  Varun Tej And Rana Dagubati Making Fun With Sa...
# 6512   NgEgYjvh6rE  FilterCopy | Types Of Men You Meet On A Date |...
# 6514   NgsoF5QeG4c  13, 14  heavy rains in chennai, Nov 13, 14 che...
# 14517  r0wnuv1X1Z0  Samantha , Naga Chaitanya Wedding Reception he...
# 12944  l3fRny54z4U  സൗബിനെ വെറും  30 സെക്കൻഡ് സമയം കൊണ്ട് വളച്ചെടു...
#
#        channel_title  category_id              state        lat        lon  \
# 16280     Film Jalsa           24              Delhi  28.669993  77.230004
# 6512      FilterCopy           23     Andhra Pradesh  14.750429  78.570026
# 6514    Red Pix 24x7           25             Kerala   8.900373  76.569993
# 14517  ETV Telangana           25  Jammu And Kashmir  34.299959  74.466658
# 12944        Asianet           24              Delhi  28.669993  77.230004
#
#                               geometry  comments_disabled  ratings_disabled  \
# 16280   POINT (77.23000403 28.6699929)              False             False
# 6512    POINT (78.57002559 14.7504291)              False             False
# 6514   POINT (76.56999263 8.900372741)              False             False
# 14517  POINT (74.46665849 34.29995933)              False             False
# 12944   POINT (77.23000403 28.6699929)              False             False
#
#        ...    views  likes dislikes  comment_count  trending_count  \
# 16280  ...    16825     31       12              2               1
# 6512   ...  1014724  25413      891           1030               1
# 6514   ...    22933     83       28             17               1
# 14517  ...    24276      1        1              1               1
# 12944  ...    54861    247       20             10               1
#
#                         kind  \
# 16280  youtube#videoCategory
# 6512   youtube#videoCategory
# 6514   youtube#videoCategory
# 14517  youtube#videoCategory
# 12944  youtube#videoCategory
#
#                                                     etag  \
# 16280  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
# 6512   "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
# 6514   "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
# 14517  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
# 12944  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#
#               snippet.channelId    snippet.title snippet.assignable
# 16280  UCBR8-60-B28hp2BmDPdntcQ    Entertainment               True
# 6512   UCBR8-60-B28hp2BmDPdntcQ           Comedy               True
# 6514   UCBR8-60-B28hp2BmDPdntcQ  News & Politics               True
# 14517  UCBR8-60-B28hp2BmDPdntcQ  News & Politics               True
# 12944  UCBR8-60-B28hp2BmDPdntcQ    Entertainment               True
#
# [5 rows x 23 columns]

# %% [markdown]
# Como se observa, la tendencia de los videos comienzan el 14 de noviembre del 2017 en el dataset.

# %%
data_cat.sort_values(by="trending_date", ascending=False).head()
# Out:
#           video_id                                              title  \
# 0           #NAME?  #DeepthiSunaina Cheema joke chepthe navvali..N...
# 10581  c7MwlTFQBEQ  Soorma | Official Trailer | Diljit Dosanjh | T...
# 13967  p1b_ZI-KRlA  8:00 AM - CURRENT AFFAIRS SHOW 13th June | RRB...
# 10305  bBc42Ov4mh8  13June 2018 करेंट अफेयर्स हिंदी//रटलेना//Daily...
# 14967  smcUETnz2xY  Sri Reddy Reacts On Nani's Legal Notices | Fil...
#
#                             channel_title  category_id        state  \
# 0                                Star Maa           24    Meghalaya
# 10581  Sony Pictures Networks Productions           24      Mizoram
# 13967                           WiFiStudy           27      Haryana
# 10305                Golden Era Education           27  West Bengal
# 14967                          Film Jalsa           24      Tripura
#
#              lat        lon                               geometry  \
# 0      25.570492  91.880014  POINT (91.88001420000001 25.57049217)
# 10581  23.710399  92.720015  POINT (92.72001461000001 23.71039899)
# 13967  28.450006  77.019991        POINT (77.01999101 28.45000633)
# 10305  22.580390  88.329947        POINT (88.32994665 22.58039044)
# 14967  23.835404  91.279999        POINT (91.27999914 23.83540428)
#
#        comments_disabled  ratings_disabled  ...    views   likes dislikes  \
# 0                  False             False  ...  1014376    5974     1414
# 10581              False             False  ...  6725073  242373     3569
# 13967              False             False  ...    59711    3571       92
# 10305              False             False  ...    59328    2232       97
# 14967              False             False  ...   313505     917     3977
#
#        comment_count  trending_count                   kind  \
# 0               1132               2  youtube#videoCategory
# 10581          14606               3  youtube#videoCategory
# 13967            235               1  youtube#videoCategory
# 10305           1296               1  youtube#videoCategory
# 14967            945               3  youtube#videoCategory
#
#                                                     etag  \
# 0      "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
# 10581  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
# 13967  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
# 10305  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
# 14967  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#
#               snippet.channelId  snippet.title snippet.assignable
# 0      UCBR8-60-B28hp2BmDPdntcQ  Entertainment               True
# 10581  UCBR8-60-B28hp2BmDPdntcQ  Entertainment               True
# 13967  UCBR8-60-B28hp2BmDPdntcQ      Education               True
# 10305  UCBR8-60-B28hp2BmDPdntcQ      Education               True
# 14967  UCBR8-60-B28hp2BmDPdntcQ  Entertainment               True
#
# [5 rows x 23 columns]

# %% [markdown]
# La tendencia de video en el dataset terminan el 14 de junio del 2018. Debido a que el dataset comprende los videos con unos 8 meses de diferencia, se evaluará la tendencia de videos por meses.

# %%
tendencia = data_cat[["trending_date"]]

# %%
tendencia
# Out:
#       trending_date
# 0        2018-06-14
# 1        2018-01-12
# 2        2018-04-25
# 3        2018-02-28
# 4        2017-12-12
# ...             ...
# 16804    2018-02-15
# 16805    2018-06-01
# 16806    2018-01-31
# 16807    2018-04-18
# 16808    2018-05-02
#
# [16809 rows x 1 columns]

# %%
tendencia['year-month'] = pd.to_datetime(tendencia['trending_date']).dt.strftime('%Y-%m')
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_34420\1451438810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tendencia['year-month'] = pd.to_datetime(tendencia['trending_date']).dt.strftime('%Y-%m')

# %%
tendencia
# Out:
#       trending_date year-month
# 0        2018-06-14    2018-06
# 1        2018-01-12    2018-01
# 2        2018-04-25    2018-04
# 3        2018-02-28    2018-02
# 4        2017-12-12    2017-12
# ...             ...        ...
# 16804    2018-02-15    2018-02
# 16805    2018-06-01    2018-06
# 16806    2018-01-31    2018-01
# 16807    2018-04-18    2018-04
# 16808    2018-05-02    2018-05
#
# [16809 rows x 2 columns]

# %%
tendencia = tendencia.groupby(["year-month"]).size().reset_index(name="videos")

# %%
tendencia
# Out:
#   year-month  videos
# 0    2017-11    1558
# 1    2017-12    2898
# 2    2018-01    2755
# 3    2018-02    2408
# 4    2018-03    2371
# 5    2018-04    1754
# 6    2018-05    2094
# 7    2018-06     971

# %%
plt.plot_date(tendencia["year-month"], tendencia["videos"], linestyle='solid')
plt.savefig('../graph/volumen_vid_tendencia.png')

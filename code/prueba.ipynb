# %%
# %store -r data
data
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc    2017-11-14
# 1      zUZ1z7FwLc8    2017-11-14
# 2      10L1hZ9qa58    2017-11-14
# 3      N1vE8iiEg64    2017-11-14
# 4      kJzGH0PVQHQ    2017-11-14
# ...            ...           ...
# 38528  iNHecA3PJCo    2018-06-14
# 38529  dpPmPbhcslM    2018-06-14
# 38530  mV6aztP58f8    2018-06-14
# 38531  qxqDNP1bDEw    2018-06-14
# 38532  wERgpPK44w0    2018-06-14
#
#                                                    title       channel_title  \
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...     Lokdhun Punjabi
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...             HJ NEWS
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...                TFPC
# 3                         Eruma Saani | Tamil vs English         Eruma Saani
# 4      why Samantha became EMOTIONAL @ Samantha naga ...          Filmylooks
# ...                                                  ...                 ...
# ...

# %%
# %store -r data_cat

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from common import showCatsBy, outliersToMax

# %%
import common as fxs

# %%
fxs.showCatsBy('likes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21352\2071091452.py in <module>
# ----> 1 fxs.showCatsBy('likes')
#
# d:\UPC-CC\AdminDeLaInformacion\EB-2022-1-CC50\code\common.py in showCatsBy(by)
#       1 import pandas as pd
# ----> 2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#
# NameError: name 'plt' is not defined
